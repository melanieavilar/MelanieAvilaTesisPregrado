# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 1830953, 'end': 1831657, 'direction': 'reverse'},
    {'name': 'EutJ', 'start': 1830035, 'end': 1830865, 'direction': 'reverse'},
    {'name': 'pocR', 'start': 1828912, 'end': 1829988, 'direction': 'forward'},
    {'name': 'A', 'start': 1828380, 'end': 1828658, 'direction': 'reverse'},
    {'name': 'B', 'start': 1827566, 'end': 1828279, 'direction': 'reverse'},
    {'name': 'C', 'start': 1825865, 'end': 1827538, 'direction': 'reverse'},
    {'name': 'D', 'start': 1825137, 'end': 1825844, 'direction': 'reverse'},
    {'name': 'E', 'start': 1824609, 'end': 1825121, 'direction': 'reverse'},
    {'name': 'G', 'start': 1822728, 'end': 1824575, 'direction': 'reverse'},
    {'name': 'H', 'start': 1822382, 'end': 1822738, 'direction': 'reverse'},
    {'name': 'K', 'start': 1821805, 'end': 1822371, 'direction': 'reverse'},
    {'name': 'J', 'start': 1821502, 'end': 1821789, 'direction': 'reverse'},
    {'name': 'L', 'start': 1820829, 'end': 1821470, 'direction': 'reverse'},
    {'name': 'M', 'start': 1820294, 'end': 1820794, 'direction': 'reverse'},
    {'name': 'N', 'start': 1820034, 'end': 1820303, 'direction': 'reverse'},
    {'name': 'O', 'start': 1819426, 'end': 1820010, 'direction': 'reverse'},
    {'name': 'Obis', 'start': 1818950, 'end': 1819420, 'direction': 'reverse'},
    {'name': 'P', 'start': 1817514, 'end': 1818944, 'direction': 'reverse'},
    {'name': 'Q', 'start': 1816375, 'end': 1817511, 'direction': 'reverse'},
    {'name': 'W', 'start': 1815167, 'end': 1816348, 'direction': 'reverse'},
    {'name': 'U', 'start': 1814804, 'end': 1815148, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'] == 'pocR':
        facecolor = 'gold'  # Custom color for 'pocR'
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'], ha='center', va='center', fontsize=16)


ax.set_xlim(1814804, 1831659)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('a) Limosilactobacillus reuteri strain reuteri CP045049.1', fontsize=18, loc='left', fontstyle='italic')

plt.savefig('x Limosilactobacillus reuteri strain reuteri CP045049.1.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'pocR', 'start': 16391, 'end': 17149, 'direction': 'forward'},
    {'name': 'A', 'start': 15754, 'end': 16044, 'direction': 'reverse'},
    {'name': 'B', 'start': 14896, 'end': 15717, 'direction': 'reverse'},
    {'name': 'C', 'start': 13201, 'end': 14721, 'direction': 'reverse'},
    {'name': 'D', 'start': 12480, 'end': 12917, 'direction': 'reverse'},
    {'name': 'E', 'start': 11939, 'end': 12457, 'direction': 'reverse'},
    {'name': 'G', 'start': 10091, 'end': 11920, 'direction': 'reverse'},
    {'name': 'H', 'start': 9739, 'end': 10086, 'direction': 'reverse'},
    {'name': 'K', 'start': 9026, 'end': 9718, 'direction': 'reverse'},
    {'name': 'J', 'start': 8729, 'end': 9010, 'direction': 'reverse'},
    {'name': 'L', 'start': 8049, 'end': 8693, 'direction': 'reverse'},
    {'name': 'M', 'start': 7516, 'end': 8016, 'direction': 'reverse'},
    {'name': 'N', 'start': 7265, 'end': 7525, 'direction': 'reverse'},
    {'name': 'O', 'start': 6668, 'end': 7243, 'direction': 'reverse'},
    {'name': 'Obis', 'start': 6171, 'end': 6662, 'direction': 'reverse'},
    {'name': 'P', 'start': 4723, 'end': 6165, 'direction': 'reverse'},
    {'name': 'Q', 'start': 3598, 'end': 4716, 'direction': 'reverse'},
    {'name': 'W', 'start': 2388, 'end': 3572, 'direction': 'reverse'},
    {'name': 'U', 'start': 2017, 'end': 2358, 'direction': 'reverse'},
    {'name': 'S', 'start': 946, 'end': 1998, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'] == 'pocR':
        facecolor = 'gold'  # Custom color for 'pocR'
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'], ha='center', va='center', fontsize=16)


ax.set_xlim(946, 17149)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('a) Secondilactobacillus collinoides', fontsize=18, loc='left', fontstyle='italic')

plt.savefig('Secondilactobacillus collinoides.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'A', 'start': 4299348, 'end': 4299629, 'direction': 'forward'},
    {'name': 'B', 'start': 4299629, 'end': 4300438, 'direction': 'forward'},
    {'name': 'C', 'start': 4300460, 'end': 4302121, 'direction': 'forward'},
    {'name': 'D', 'start': 4302135, 'end': 4302821, 'direction': 'forward'},
    {'name': 'E', 'start': 4302839, 'end': 4303360, 'direction': 'forward'},
    {'name': 'G', 'start': 4303376, 'end': 4305205, 'direction': 'forward'},
    {'name': 'H', 'start': 4305150, 'end': 4305545, 'direction': 'forward'},
    {'name': 'J', 'start': 4305567, 'end': 4305839, 'direction': 'forward'},
    {'name': 'K', 'start': 4305930, 'end': 4306307, 'direction': 'forward'},
    {'name': 'L', 'start': 4306310, 'end': 4306939, 'direction': 'forward'},
    {'name': 'M', 'start': 4306939, 'end': 4307427, 'direction': 'forward'},
    {'name': 'N', 'start': 4307434, 'end': 4307706, 'direction': 'forward'},
    {'name': 'O', 'start': 4307657, 'end': 4308733, 'direction': 'forward'},
    {'name': 'P', 'start': 4308733, 'end': 4310118, 'direction': 'forward'},
    {'name': 'Q', 'start': 4310133, 'end': 4311242, 'direction': 'forward'},
    {'name': 'U', 'start': 4313151, 'end': 4313498, 'direction': 'forward'},
    {'name': 'S', 'start': 4311242, 'end': 4312591, 'direction': 'forward'},
    {'name': 'T', 'start': 4312597, 'end': 4313148, 'direction': 'forward'},
    {'name': 'U', 'start': 4313151, 'end': 4313498, 'direction': 'forward'},
    {'name': 'V', 'start': 4313506, 'end': 4313943, 'direction': 'forward'},
    {'name': 'W', 'start': 4313943, 'end': 4315154, 'direction': 'forward'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'] == 'pocR':
        facecolor = 'gold'  # Custom color for 'pocR'
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'], ha='center', va='center', fontsize=16)


ax.set_xlim(4299346, 4315154)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('c) Klebsiella pneumoniae', fontsize=18, loc='left', fontstyle='italic')

plt.savefig('Klebsiella pneumoniae.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'pocR', 'start': 2114399, 'end': 2115307, 'direction': 'reverse'},
    {'name': 'F', 'start': 2115527, 'end': 2116606, 'direction': 'reverse'},
    {'name': 'A', 'start': 2116843, 'end': 2117118, 'direction': 'forward'},
    {'name': 'B', 'start': 2117124, 'end': 2117933, 'direction': 'forward'},
    {'name': 'C', 'start': 2117955, 'end': 2119616, 'direction': 'forward'},
    {'name': 'D', 'start': 2119630, 'end': 2120301, 'direction': 'forward'},
    {'name': 'E', 'start': 2120319, 'end': 2120837, 'direction': 'forward'},
    {'name': 'G', 'start': 2120850, 'end': 2122679, 'direction': 'forward'},
    {'name': 'H', 'start': 2122672, 'end': 2123019, 'direction': 'forward'},
    {'name': 'J', 'start': 2123041, 'end': 2123313, 'direction': 'forward'},
    {'name': 'K', 'start': 2123320, 'end': 2123799, 'direction': 'forward'},
    {'name': 'L', 'start': 2123802, 'end': 2124431, 'direction': 'forward'},
    {'name': 'M', 'start': 2124431, 'end': 2124919, 'direction': 'forward'},
    {'name': 'N', 'start': 2124926, 'end': 2125195, 'direction': 'forward'},
    {'name': 'O', 'start': 2125211, 'end': 2126218, 'direction': 'forward'},
    {'name': 'P', 'start': 2126218, 'end': 2127609, 'direction': 'forward'},
    {'name': 'Q', 'start': 2127624, 'end': 2128733, 'direction': 'forward'},
    {'name': 'U', 'start': 2130645, 'end': 2130992, 'direction': 'forward'},
    {'name': 'S', 'start': 2128733, 'end': 2130085, 'direction': 'forward'},
    {'name': 'T', 'start': 2130091, 'end': 2130642, 'direction': 'forward'},
    {'name': 'U', 'start': 2130645, 'end': 2130992, 'direction': 'forward'},
    {'name': 'V', 'start': 2131000, 'end': 2131449, 'direction': 'forward'},
    {'name': 'W', 'start': 2131437, 'end': 2132648, 'direction': 'forward'},
    {'name': 'W', 'start': 2132709, 'end': 2133608, 'direction': 'forward'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'] == 'pocR':
        facecolor = 'gold'  # Custom color for 'pocR'
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'], ha='center', va='center', fontsize=16)


ax.set_xlim(2114399, 2133608)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('d) Salmonella Typhimurium', fontsize=18, loc='left', fontstyle='italic')

plt.savefig('Salmonella Typhimurium.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 1748212, 'end': 1748916, 'direction': 'reverse'},
    {'name': 'EutJ ', 'start': 1747294, 'end': 1748124, 'direction': 'reverse'},
    {'name': 'pocR ', 'start': 1746171, 'end': 1747247, 'direction': 'forward'},
    {'name': 'A', 'start': 1745639, 'end': 1745917, 'direction': 'reverse'},
    {'name': 'B', 'start': 1744825, 'end': 1745538, 'direction': 'reverse'},
    {'name': 'C', 'start': 1743124, 'end': 1744797, 'direction': 'reverse'},
    {'name': 'D', 'start': 1742396, 'end': 1743103, 'direction': 'reverse'},
    {'name': 'E', 'start': 1741868, 'end': 1742380, 'direction': 'reverse'},
    {'name': 'G', 'start': 1739987, 'end': 1741834, 'direction': 'reverse'},
    {'name': 'H', 'start': 1739641, 'end': 1739997, 'direction': 'reverse'},
    {'name': 'K', 'start': 1739064, 'end': 1739630, 'direction': 'reverse'},
    {'name': 'J', 'start': 1738761, 'end': 1739048, 'direction': 'reverse'},
    {'name': 'L', 'start': 1738088, 'end': 1738729, 'direction': 'reverse'},
    {'name': 'M', 'start': 1737553, 'end': 1738053, 'direction': 'reverse'},
    {'name': 'N', 'start': 1737293, 'end': 1737562, 'direction': 'reverse'},
    {'name': 'O', 'start': 1736685, 'end': 1737269, 'direction': 'reverse'},
    {'name': 'Obis', 'start': 1736209, 'end': 1736679, 'direction': 'reverse'},
    {'name': 'P', 'start': 1734773, 'end': 1736203, 'direction': 'reverse'},
    {'name': 'Q', 'start': 1733634, 'end': 1734770, 'direction': 'reverse'},
    {'name': 'W', 'start': 1732426, 'end': 1733607, 'direction': 'reverse'},
    {'name': 'U', 'start': 1732063, 'end': 1732407, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(1732063, 1748916)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain MG4722 chromosome, complete genome Sequence ID: CP162612.1', fontsize=18, loc='left', fontstyle='italic')

plt.savefig('x Limosilactobacillus reuteri strain MG4722 chromosome Sequence ID CP162612.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 1128289, 'end': 1128993, 'direction': 'reverse'},
    {'name': 'EutJ', 'start': 1127371, 'end': 1128201, 'direction': 'reverse'},
    {'name': 'pocR', 'start': 1126248, 'end': 1127324, 'direction': 'forward'},
    {'name': 'A', 'start': 1125716, 'end': 1125994, 'direction': 'reverse'},
    {'name': 'B', 'start': 1124902, 'end': 1125615, 'direction': 'reverse'},
    {'name': 'C', 'start': 1123201, 'end': 1124874, 'direction': 'reverse'},
    {'name': 'D', 'start': 1122473, 'end': 1123180, 'direction': 'reverse'},
    {'name': 'E', 'start': 1121945, 'end': 1122457, 'direction': 'reverse'},
    {'name': 'G', 'start': 1120064, 'end': 1121911, 'direction': 'reverse'},
    {'name': 'H', 'start': 1119718, 'end': 1120074, 'direction': 'reverse'},
    {'name': 'K', 'start': 1119141, 'end': 1119707, 'direction': 'reverse'},
    {'name': 'J', 'start': 1118838, 'end': 1119125, 'direction': 'reverse'},
    {'name': 'L', 'start': 1118165, 'end': 1118806, 'direction': 'reverse'},
    {'name': 'M', 'start': 1117630, 'end': 1118130, 'direction': 'reverse'},
    {'name': 'N', 'start': 1117370, 'end': 1117639, 'direction': 'reverse'},
    {'name': 'O', 'start': 1116762, 'end': 1117346, 'direction': 'reverse'},
    {'name': 'Obis', 'start': 1116286, 'end': 1116756, 'direction': 'reverse'},
    {'name': 'P', 'start': 1114850, 'end': 1116280, 'direction': 'reverse'},
    {'name': 'Q', 'start': 1113711, 'end': 1114847, 'direction': 'reverse'},
    {'name': 'W', 'start': 1112503, 'end': 1113684, 'direction': 'reverse'},
    {'name': 'U', 'start': 1112140, 'end': 1112484, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR':  # Strip any extra spaces
        facecolor = 'gold'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(1112140, 1128993)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain EFEL6901 chromosome, complete genome Sequence ID: CP095735.1', fontsize=18, loc='left', fontstyle='italic')

plt.savefig('x Limosilactobacillus reuteri strain EFEL6901 chromosome Sequence ID  CP095735.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
	{'name': 'F', 'start': 1317452, 'end': 1318156, 'direction': 'forward'},
	{'name': 'EutJ ', 'start': 1318244, 'end': 1319074, 'direction': 'forward'},
	{'name': 'pocR ', 'start': 1319223, 'end': 1320197, 'direction': 'reverse'},
	{'name': 'A', 'start': 1320451, 'end': 1320729, 'direction': 'forward'},
	{'name': 'B', 'start': 1320830, 'end': 1321543, 'direction': 'forward'},
	{'name': 'C', 'start': 1321571, 'end': 1323244, 'direction': 'forward'},
	{'name': 'D', 'start': 1323265, 'end': 1323972, 'direction': 'forward'},
	{'name': 'E', 'start': 1323988, 'end': 1324500, 'direction': 'forward'},
	{'name': 'G', 'start': 1324534, 'end': 1326381, 'direction': 'forward'},
	{'name': 'H', 'start': 1326371, 'end': 1326727, 'direction': 'forward'},
	{'name': 'K', 'start': 1326738, 'end': 1327304, 'direction': 'forward'},
	{'name': 'J', 'start': 1327320, 'end': 1327607, 'direction': 'forward'},
	{'name': 'L', 'start': 1327639, 'end': 1328280, 'direction': 'forward'},
	{'name': 'M', 'start': 1328315, 'end': 1328815, 'direction': 'forward'},
	{'name': 'N', 'start': 1328806, 'end': 1329075, 'direction': 'forward'},
	{'name': 'O', 'start': 1329099, 'end': 1329683, 'direction': 'forward'},
	{'name': 'Obis', 'start': 1329689, 'end': 1330159, 'direction': 'forward'},
	{'name': 'P', 'start': 1330165, 'end': 1331595, 'direction': 'forward'},
	{'name': 'Q', 'start': 1331598, 'end': 1332734, 'direction': 'forward'},
    {'name': 'W', 'start': 1332761, 'end': 1333942, 'direction': 'forward'},
	{'name': 'U', 'start': 1333961, 'end': 1334305, 'direction': 'forward'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(1317452, 1334305)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain RTR chromosome, complete genome, ID: CP073062.1', fontsize=18, loc='left', fontstyle='italic')

plt.savefig('x Limosilactobacillus reuteri strain RTR Sequence ID CP073062.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
	{'name': 'F', 'start': 1799670, 'end': 1800374, 'direction': 'reverse'},
	{'name': 'EutJ ', 'start': 1798752, 'end': 1799582, 'direction': 'reverse'},
	{'name': 'pocR ', 'start': 1797629, 'end': 1798705, 'direction': 'forward'},
	{'name': 'A', 'start': 1797097, 'end': 1797375, 'direction': 'reverse'},
	{'name': 'B', 'start': 1796283, 'end': 1796996, 'direction': 'reverse'},
	{'name': 'C', 'start': 1794582, 'end': 1796255, 'direction': 'reverse'},
	{'name': 'D', 'start': 1793854, 'end': 1794561, 'direction': 'reverse'},
	{'name': 'E', 'start': 1793326, 'end': 1793838, 'direction': 'reverse'},
	{'name': 'G', 'start': 1791445, 'end': 1793292, 'direction': 'reverse'},
	{'name': 'H', 'start': 1791099, 'end': 1791455, 'direction': 'reverse'},
	{'name': 'K', 'start': 1790522, 'end': 1791088, 'direction': 'reverse'},
	{'name': 'J', 'start': 1790219, 'end': 1790506, 'direction': 'reverse'},
	{'name': 'L', 'start': 1789546, 'end': 1790187, 'direction': 'reverse'},
	{'name': 'M', 'start': 1789011, 'end': 1789511, 'direction': 'reverse'},
	{'name': 'N', 'start': 1788751, 'end': 1789020, 'direction': 'reverse'},
	{'name': 'O', 'start': 1788143, 'end': 1788727, 'direction': 'reverse'},
	{'name': 'Obis', 'start': 1787667, 'end': 1788137, 'direction': 'reverse'},
	{'name': 'P', 'start': 1786231, 'end': 1787661, 'direction': 'reverse'},
	{'name': 'Q', 'start': 1785092, 'end': 1786228, 'direction': 'reverse'},
	{'name': 'W', 'start': 1783884, 'end': 1785065, 'direction': 'reverse'},
	{'name': 'U', 'start': 1783521, 'end': 1783865, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(1783521, 1800374)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Lactobacillus reuteri strain IRT, complete genome Sequence ID: CP011024.1', fontsize=18, loc='left', fontstyle='italic')

plt.savefig('x Lactobacillus reuteri strain IRT Sequence ID CP011024.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
	{'name': 'F', 'start': 1805321, 'end': 1806025, 'direction': 'reverse'},
	{'name': 'EutJ', 'start': 1804403, 'end': 1805233, 'direction': 'reverse'},
	{'name': 'pocR ', 'start': 1803280, 'end': 1804356, 'direction': 'forward'},
	{'name': 'A', 'start': 1802748, 'end': 1803026, 'direction': 'reverse'},
	{'name': 'B', 'start': 1801934, 'end': 1802647, 'direction': 'reverse'},
	{'name': 'C', 'start': 1800233, 'end': 1801906, 'direction': 'reverse'},
	{'name': 'D', 'start': 1799505, 'end': 1800212, 'direction': 'reverse'},
	{'name': 'E', 'start': 1798977, 'end': 1799489, 'direction': 'reverse'},
	{'name': 'G', 'start': 1797096, 'end': 1798943, 'direction': 'reverse'},
	{'name': 'H', 'start': 1796750, 'end': 1797106, 'direction': 'reverse'},
	{'name': 'K', 'start': 1796173, 'end': 1796739, 'direction': 'reverse'},
	{'name': 'J', 'start': 1795870, 'end': 1796157, 'direction': 'reverse'},
	{'name': 'L', 'start': 1795197, 'end': 1795838, 'direction': 'reverse'},
	{'name': 'M', 'start': 1794662, 'end': 1795162, 'direction': 'reverse'},
	{'name': 'N', 'start': 1794402, 'end': 1794671, 'direction': 'reverse'},
	{'name': 'O', 'start': 1793794, 'end': 1794378, 'direction': 'reverse'},
	{'name': 'Obis', 'start': 1793318, 'end': 1793788, 'direction': 'reverse'},
	{'name': 'P', 'start': 1791882, 'end': 1793312, 'direction': 'reverse'},
	{'name': 'Q', 'start': 1790743, 'end': 1791879, 'direction': 'reverse'},
	{'name': 'W', 'start': 1789535, 'end': 1790716, 'direction': 'reverse'},
	{'name': 'U', 'start': 1789172, 'end': 1789516, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(1789172, 1806025)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Lactobacillus reuteri DSM 20016, complete genome Sequence ID: CP000705.1', fontsize=18, loc='left', fontstyle='italic')

plt.savefig('x Lactobacillus reuteri DSM 20016 Sequence ID CP000705.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
	{'name': 'F', 'start': 1844238, 'end': 1844942, 'direction': 'reverse'},
	{'name': 'EutJ ', 'start': 1843320, 'end': 1844150, 'direction': 'reverse'},
	{'name': 'pocR ', 'start': 1842197, 'end': 1843273, 'direction': 'forward'},
	{'name': 'A', 'start': 1841665, 'end': 1841943, 'direction': 'reverse'},
	{'name': 'B', 'start': 1840851, 'end': 1841564, 'direction': 'reverse'},
	{'name': 'C', 'start': 1839150, 'end': 1840823, 'direction': 'reverse'},
	{'name': 'D', 'start': 1838422, 'end': 1839129, 'direction': 'reverse'},
	{'name': 'E', 'start': 1837894, 'end': 1838406, 'direction': 'reverse'},
	{'name': 'G', 'start': 1836013, 'end': 1837860, 'direction': 'reverse'},
	{'name': 'H', 'start': 1835667, 'end': 1836023, 'direction': 'reverse'},
	{'name': 'K', 'start': 1835090, 'end': 1835656, 'direction': 'reverse'},
	{'name': 'J', 'start': 1834787, 'end': 1835074, 'direction': 'reverse'},
	{'name': 'L', 'start': 1834114, 'end': 1834755, 'direction': 'reverse'},
	{'name': 'M', 'start': 1833579, 'end': 1834079, 'direction': 'reverse'},
	{'name': 'N', 'start': 1833319, 'end': 1833588, 'direction': 'reverse'},
	{'name': 'O', 'start': 1832711, 'end': 1833295, 'direction': 'reverse'},
	{'name': 'Obis', 'start': 1832235, 'end': 1832705, 'direction': 'reverse'},
	{'name': 'P', 'start': 1830799, 'end': 1832229, 'direction': 'reverse'},
	{'name': 'Q', 'start': 1829660, 'end': 1830796, 'direction': 'reverse'},
	{'name': 'W', 'start': 1828452, 'end': 1829633, 'direction': 'reverse'},
	{'name': 'U', 'start': 1828089, 'end': 1828433, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(1828089, 1844942)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain TK-F8A chromosome, complete genome Sequence ID: CP045605.1', fontsize=18, loc='left', fontstyle='italic')

plt.savefig('x Limosilactobacillus reuteri strain TK-F8A Sequence ID CP045605.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
	{'name': 'F', 'start': 1844730, 'end': 1845434, 'direction': 'reverse'},
	{'name': 'EutJ ', 'start': 1843812, 'end': 1844642, 'direction': 'reverse'},
	{'name': 'pocR ', 'start': 1842689, 'end': 1843765, 'direction': 'forward'},
	{'name': 'A', 'start': 1842157, 'end': 1842435, 'direction': 'reverse'},
	{'name': 'B', 'start': 1841343, 'end': 1842056, 'direction': 'reverse'},
	{'name': 'C', 'start': 1839642, 'end': 1841315, 'direction': 'reverse'},
	{'name': 'D', 'start': 1838914, 'end': 1839621, 'direction': 'reverse'},
	{'name': 'E', 'start': 1838386, 'end': 1838898, 'direction': 'reverse'},
	{'name': 'G', 'start': 1836505, 'end': 1838352, 'direction': 'reverse'},
	{'name': 'H', 'start': 1836159, 'end': 1836515, 'direction': 'reverse'},
	{'name': 'K', 'start': 1835582, 'end': 1836148, 'direction': 'reverse'},
	{'name': 'J', 'start': 1835279, 'end': 1835566, 'direction': 'reverse'},
	{'name': 'L', 'start': 1834606, 'end': 1835247, 'direction': 'reverse'},
	{'name': 'M', 'start': 1834071, 'end': 1834571, 'direction': 'reverse'},
	{'name': 'N', 'start': 1833811, 'end': 1834080, 'direction': 'reverse'},
	{'name': 'O', 'start': 1833203, 'end': 1833787, 'direction': 'reverse'},
	{'name': 'Obis', 'start': 1832727, 'end': 1833197, 'direction': 'reverse'},
	{'name': 'P', 'start': 1831291, 'end': 1832721, 'direction': 'reverse'},
	{'name': 'Q', 'start': 1830152, 'end': 1831288, 'direction': 'reverse'},
	{'name': 'W', 'start': 1828944, 'end': 1830125, 'direction': 'reverse'},
	{'name': 'U', 'start': 1828581, 'end': 1828925, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(1828581, 1845434)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain LU150 chromosome, complete genome Sequence ID: CP147911.1', fontsize=18, loc='left', fontstyle='italic')

plt.savefig('x Limosilactobacillus reuteri strain LU150 Sequence ID CP147911.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 1844737, 'end': 1845441, 'direction': 'reverse'},
    {'name': 'EutJ ', 'start': 1843819, 'end': 1844649, 'direction': 'reverse'},
    {'name': 'pocR ', 'start': 1842696, 'end': 1843772, 'direction': 'forward'},
    {'name': 'A', 'start': 1842164, 'end': 1842442, 'direction': 'reverse'},
    {'name': 'B', 'start': 1841350, 'end': 1842063, 'direction': 'reverse'},
    {'name': 'C', 'start': 1839649, 'end': 1841322, 'direction': 'reverse'},
    {'name': 'D', 'start': 1838921, 'end': 1839628, 'direction': 'reverse'},
    {'name': 'E', 'start': 1838393, 'end': 1838905, 'direction': 'reverse'},
    {'name': 'G', 'start': 1836512, 'end': 1838359, 'direction': 'reverse'},
    {'name': 'H', 'start': 1836166, 'end': 1836522, 'direction': 'reverse'},
    {'name': 'K', 'start': 1835589, 'end': 1836155, 'direction': 'reverse'},
    {'name': 'J', 'start': 1835286, 'end': 1835573, 'direction': 'reverse'},
    {'name': 'L', 'start': 1834613, 'end': 1835254, 'direction': 'reverse'},
    {'name': 'M', 'start': 1834078, 'end': 1834578, 'direction': 'reverse'},
    {'name': 'N', 'start': 1833818, 'end': 1834087, 'direction': 'reverse'},
    {'name': 'O', 'start': 1833210, 'end': 1833794, 'direction': 'reverse'},
    {'name': 'Obis', 'start': 1832734, 'end': 1833204, 'direction': 'reverse'},
    {'name': 'P', 'start': 1831298, 'end': 1832728, 'direction': 'reverse'},
    {'name': 'Q', 'start': 1830159, 'end': 1831295, 'direction': 'reverse'},
    {'name': 'W', 'start': 1828951, 'end': 1830132, 'direction': 'reverse'},
    {'name': 'U', 'start': 1828588, 'end': 1828932, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(1828588, 1845441)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Lactobacillus reuteri JCM 1112 DNA, complete genome Sequence ID: AP007281.1', fontsize=18, loc='left', fontstyle='italic')

plt.savefig('x Lactobacillus reuteri JCM 1112 DNA Sequence ID AP007281.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 1844835, 'end': 1845539, 'direction': 'reverse'},
    {'name': 'EutJ ', 'start': 1843917, 'end': 1844747, 'direction': 'reverse'},
    {'name': 'pocR ', 'start': 1842794, 'end': 1843870, 'direction': 'reverse'},
    {'name': 'A', 'start': 1842262, 'end': 1842540, 'direction': 'reverse'},
    {'name': 'B', 'start': 1841448, 'end': 1842161, 'direction': 'reverse'},
    {'name': 'C', 'start': 1839747, 'end': 1841420, 'direction': 'reverse'},
    {'name': 'D', 'start': 1839019, 'end': 1839726, 'direction': 'reverse'},
    {'name': 'E', 'start': 1838491, 'end': 1839003, 'direction': 'reverse'},
    {'name': 'G', 'start': 1836610, 'end': 1838457, 'direction': 'reverse'},
    {'name': 'H', 'start': 1836264, 'end': 1836620, 'direction': 'reverse'},
    {'name': 'K', 'start': 1835687, 'end': 1836253, 'direction': 'reverse'},
    {'name': 'J', 'start': 1835384, 'end': 1835671, 'direction': 'reverse'},
    {'name': 'L', 'start': 1834711, 'end': 1835352, 'direction': 'reverse'},
    {'name': 'M', 'start': 1834176, 'end': 1834676, 'direction': 'reverse'},
    {'name': 'N', 'start': 1833916, 'end': 1834185, 'direction': 'reverse'},
    {'name': 'O', 'start': 1833308, 'end': 1833892, 'direction': 'reverse'},
    {'name': 'Obis', 'start': 1832832, 'end': 1833302, 'direction': 'reverse'},
    {'name': 'P', 'start': 1831396, 'end': 1832826, 'direction': 'reverse'},
    {'name': 'Q', 'start': 1830257, 'end': 1831393, 'direction': 'reverse'},
    {'name': 'W', 'start': 1829049, 'end': 1830230, 'direction': 'reverse'},
    {'name': 'U', 'start': 1828686, 'end': 1829030, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(1828686, 1845539)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain ATCC PTA 5289 chromosome, complete genome Sequence ID: CP162672.1', fontsize=18, loc='left', fontstyle='italic')

plt.savefig('x Limosilactobacillus reuteri strain ATCC PTA 5289 Sequence ID CP162672.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 1844835, 'end': 1845539, 'direction': 'reverse'},
    {'name': 'EutJ', 'start': 1843917, 'end': 1844747, 'direction': 'reverse'},
    {'name': 'pocR ', 'start': 1842794, 'end': 1843870, 'direction': 'reverse'},
    {'name': 'A', 'start': 1842262, 'end': 1842540, 'direction': 'reverse'},
    {'name': 'B', 'start': 1841448, 'end': 1842161, 'direction': 'reverse'},
    {'name': 'C', 'start': 1839747, 'end': 1841420, 'direction': 'reverse'},
    {'name': 'D', 'start': 1839019, 'end': 1839726, 'direction': 'reverse'},
    {'name': 'E', 'start': 1838491, 'end': 1839003, 'direction': 'reverse'},
    {'name': 'G', 'start': 1836610, 'end': 1838457, 'direction': 'reverse'},
    {'name': 'H', 'start': 1836264, 'end': 1836620, 'direction': 'reverse'},
    {'name': 'K', 'start': 1835687, 'end': 1836253, 'direction': 'reverse'},
    {'name': 'J', 'start': 1835384, 'end': 1835671, 'direction': 'reverse'},
    {'name': 'L', 'start': 1834711, 'end': 1835352, 'direction': 'reverse'},
    {'name': 'M', 'start': 1834176, 'end': 1834676, 'direction': 'reverse'},
    {'name': 'N', 'start': 1833916, 'end': 1834185, 'direction': 'reverse'},
    {'name': 'O', 'start': 1833308, 'end': 1833892, 'direction': 'reverse'},
    {'name': 'Obis', 'start': 1832832, 'end': 1833302, 'direction': 'reverse'},
    {'name': 'P', 'start': 1831396, 'end': 1832826, 'direction': 'reverse'},
    {'name': 'Q', 'start': 1830257, 'end': 1831393, 'direction': 'reverse'},
    {'name': 'W', 'start': 1829049, 'end': 1830230, 'direction': 'reverse'},
    {'name': 'U', 'start': 1828686, 'end': 1829030, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(1828686, 1845539)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain BG-R33 (DSM 33633) chromosome, complete genome Sequence ID: CP162645.1', fontsize=18, loc='left', fontstyle='italic')

plt.savefig('x Limosilactobacillus reuteri strain BG-R33 (DSM 33633) Sequence ID CP162645.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 1845997, 'end': 1846701, 'direction': 'reverse'},
    {'name': 'EutJ', 'start': 1845079, 'end': 1845909, 'direction': 'reverse'},
    {'name': 'pocR ', 'start': 1843956, 'end': 1845032, 'direction': 'forward'},
    {'name': 'A', 'start': 1843424, 'end': 1843702, 'direction': 'reverse'},
    {'name': 'B', 'start': 1842610, 'end': 1843323, 'direction': 'reverse'},
    {'name': 'C', 'start': 1840909, 'end': 1842582, 'direction': 'reverse'},
    {'name': 'D', 'start': 1840181, 'end': 1840888, 'direction': 'reverse'},
    {'name': 'E', 'start': 1839653, 'end': 1840165, 'direction': 'reverse'},
    {'name': 'G', 'start': 1837772, 'end': 1839619, 'direction': 'reverse'},
    {'name': 'H', 'start': 1837426, 'end': 1837782, 'direction': 'reverse'},
    {'name': 'K', 'start': 1836849, 'end': 1837415, 'direction': 'reverse'},
    {'name': 'J', 'start': 1836546, 'end': 1836833, 'direction': 'reverse'},
    {'name': 'L', 'start': 1835873, 'end': 1836514, 'direction': 'reverse'},
    {'name': 'M', 'start': 1835338, 'end': 1835838, 'direction': 'reverse'},
    {'name': 'N', 'start': 1835078, 'end': 1835347, 'direction': 'reverse'},
    {'name': 'O', 'start': 1834470, 'end': 1835054, 'direction': 'reverse'},
    {'name': 'Obis', 'start': 1833994, 'end': 1834464, 'direction': 'reverse'},
    {'name': 'P', 'start': 1832558, 'end': 1833988, 'direction': 'reverse'},
    {'name': 'Q', 'start': 1831419, 'end': 1832555, 'direction': 'reverse'},
    {'name': 'W', 'start': 1830211, 'end': 1831392, 'direction': 'reverse'},
    {'name': 'U', 'start': 1829848, 'end': 1830192, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(1829848, 1846701)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain VHProbi E18 chromosome, complete genome Sequence ID: CP088931.1', fontsize=18, loc='left', fontstyle='italic')
plt.savefig('x Limosilactobacillus reuteri strain VHProbi E18 Sequence ID CP088931.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 940273, 'end': 940977, 'direction': 'reverse'},
    {'name': 'EutJ ', 'start': 939355, 'end': 940185, 'direction': 'reverse'},
    {'name': 'pocR ', 'start': 938232, 'end': 939308, 'direction': 'forward'},
    {'name': 'A', 'start': 937700, 'end': 937978, 'direction': 'reverse'},
    {'name': 'B', 'start': 936886, 'end': 937599, 'direction': 'reverse'},
    {'name': 'C', 'start': 935185, 'end': 936858, 'direction': 'reverse'},
    {'name': 'D', 'start': 934457, 'end': 935164, 'direction': 'reverse'},
    {'name': 'E', 'start': 933929, 'end': 934441, 'direction': 'reverse'},
    {'name': 'G', 'start': 932048, 'end': 933895, 'direction': 'reverse'},
    {'name': 'H', 'start': 931702, 'end': 932058, 'direction': 'reverse'},
    {'name': 'K', 'start': 931125, 'end': 931691, 'direction': 'reverse'},
    {'name': 'J', 'start': 930822, 'end': 931109, 'direction': 'reverse'},
    {'name': 'L', 'start': 930149, 'end': 930790, 'direction': 'reverse'},
    {'name': 'M', 'start': 929614, 'end': 930114, 'direction': 'reverse'},
    {'name': 'N', 'start': 929354, 'end': 929623, 'direction': 'reverse'},
    {'name': 'O', 'start': 928746, 'end': 929330, 'direction': 'reverse'},
    {'name': 'Obis', 'start': 928270, 'end': 928740, 'direction': 'reverse'},
    {'name': 'P', 'start': 926834, 'end': 928264, 'direction': 'reverse'},
    {'name': 'Q', 'start': 925695, 'end': 926831, 'direction': 'reverse'},
    {'name': 'W', 'start': 924487, 'end': 925668, 'direction': 'reverse'},
    {'name': 'U', 'start': 924124, 'end': 924468, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(924124, 940977)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain ATG-F4 chromosome, complete genome Sequence ID: CP035790.1', fontsize=18, loc='left', fontstyle='italic')
plt.savefig('x Limosilactobacillus reuteri strain ATG-F4 Sequence ID CP035790.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 1846855, 'end': 1847559, 'direction': 'reverse'},
    {'name': 'EutJ ', 'start': 1845937, 'end': 1846767, 'direction': 'reverse'},
    {'name': 'pocR ', 'start': 1844814, 'end': 1845890, 'direction': 'forward'},
    {'name': 'A', 'start': 1844282, 'end': 1844560, 'direction': 'reverse'},
    {'name': 'B', 'start': 1843468, 'end': 1844181, 'direction': 'reverse'},
    {'name': 'C', 'start': 1841767, 'end': 1843440, 'direction': 'reverse'},
    {'name': 'D', 'start': 1841039, 'end': 1841746, 'direction': 'reverse'},
    {'name': 'E', 'start': 1840511, 'end': 1841023, 'direction': 'reverse'},
    {'name': 'G', 'start': 1838630, 'end': 1840477, 'direction': 'reverse'},
    {'name': 'H', 'start': 1838284, 'end': 1838640, 'direction': 'reverse'},
    {'name': 'K', 'start': 1837707, 'end': 1838273, 'direction': 'reverse'},
    {'name': 'J', 'start': 1837404, 'end': 1837691, 'direction': 'reverse'},
    {'name': 'L', 'start': 1836731, 'end': 1837372, 'direction': 'reverse'},
    {'name': 'M', 'start': 1836196, 'end': 1836696, 'direction': 'reverse'},
    {'name': 'N', 'start': 1835936, 'end': 1836205, 'direction': 'reverse'},
    {'name': 'O', 'start': 1835328, 'end': 1835912, 'direction': 'reverse'},
    {'name': 'Obis', 'start': 1834852, 'end': 1835322, 'direction': 'reverse'},
    {'name': 'P', 'start': 1833416, 'end': 1834846, 'direction': 'reverse'},
    {'name': 'Q', 'start': 1832277, 'end': 1833413, 'direction': 'reverse'},
    {'name': 'W', 'start': 1831069, 'end': 1832250, 'direction': 'reverse'},
    {'name': 'U', 'start': 1830706, 'end': 1831050, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(1830706, 1847559)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain VHProbi M07 chromosome, complete genome Sequence ID: CP089303.1', fontsize=18, loc='left', fontstyle='italic')
plt.savefig('x Limosilactobacillus reuteri strain VHProbi M07 Sequence ID CP089303.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 1859021, 'end': 1859725, 'direction': 'reverse'},
    {'name': 'EutJ ', 'start': 1858103, 'end': 1858933, 'direction': 'reverse'},
    {'name': 'pocR ', 'start': 1856980, 'end': 1858056, 'direction': 'forward'},
    {'name': 'A', 'start': 1856448, 'end': 1856726, 'direction': 'reverse'},
    {'name': 'B', 'start': 1855634, 'end': 1856347, 'direction': 'reverse'},
    {'name': 'C', 'start': 1853933, 'end': 1855606, 'direction': 'reverse'},
    {'name': 'D', 'start': 1853205, 'end': 1853912, 'direction': 'reverse'},
    {'name': 'E', 'start': 1852677, 'end': 1853189, 'direction': 'reverse'},
    {'name': 'G', 'start': 1850796, 'end': 1852643, 'direction': 'reverse'},
    {'name': 'H', 'start': 1850450, 'end': 1850806, 'direction': 'reverse'},
    {'name': 'K', 'start': 1849873, 'end': 1850439, 'direction': 'reverse'},
    {'name': 'J', 'start': 1849570, 'end': 1849857, 'direction': 'reverse'},
    {'name': 'L', 'start': 1848897, 'end': 1849538, 'direction': 'reverse'},
    {'name': 'M', 'start': 1848362, 'end': 1848862, 'direction': 'reverse'},
    {'name': 'N', 'start': 1848102, 'end': 1848371, 'direction': 'reverse'},
    {'name': 'O', 'start': 1847494, 'end': 1848078, 'direction': 'reverse'},
    {'name': 'Obis', 'start': 1847018, 'end': 1847488, 'direction': 'reverse'},
    {'name': 'P', 'start': 1845582, 'end': 1847012, 'direction': 'reverse'},
    {'name': 'Q', 'start': 1844443, 'end': 1845579, 'direction': 'reverse'},
    {'name': 'W', 'start': 1843235, 'end': 1844416, 'direction': 'reverse'},
    {'name': 'U', 'start': 1842872, 'end': 1843216, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(1842872, 1859725)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain VHProbi V43 chromosome, complete genome Sequence ID: CP142419.1', fontsize=18, loc='left', fontstyle='italic')
plt.savefig('x Limosilactobacillus reuteri strain VHProbi V43 Sequence ID CP142419.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 1893073, 'end': 1893777, 'direction': 'reverse'},
    {'name': 'EutJ ', 'start': 1892155, 'end': 1892985, 'direction': 'reverse'},
    {'name': 'pocR ', 'start': 1891032, 'end': 1892108, 'direction': 'forward'},
    {'name': 'A', 'start': 1890500, 'end': 1890778, 'direction': 'reverse'},
    {'name': 'B', 'start': 1889686, 'end': 1890399, 'direction': 'reverse'},
    {'name': 'C', 'start': 1887985, 'end': 1889658, 'direction': 'reverse'},
    {'name': 'D', 'start': 1887257, 'end': 1887964, 'direction': 'reverse'},
    {'name': 'E', 'start': 1886729, 'end': 1887241, 'direction': 'reverse'},
    {'name': 'G', 'start': 1884848, 'end': 1886695, 'direction': 'reverse'},
    {'name': 'H', 'start': 1884502, 'end': 1884858, 'direction': 'reverse'},
    {'name': 'K', 'start': 1883925, 'end': 1884491, 'direction': 'reverse'},
    {'name': 'J', 'start': 1883622, 'end': 1883909, 'direction': 'reverse'},
    {'name': 'L', 'start': 1882949, 'end': 1883590, 'direction': 'reverse'},
    {'name': 'M', 'start': 1882414, 'end': 1882914, 'direction': 'reverse'},
    {'name': 'N', 'start': 1882154, 'end': 1882423, 'direction': 'reverse'},
    {'name': 'O', 'start': 1881546, 'end': 1882130, 'direction': 'reverse'},
    {'name': 'Obis', 'start': 1881070, 'end': 1881540, 'direction': 'reverse'},
    {'name': 'P', 'start': 1879634, 'end': 1881064, 'direction': 'reverse'},
    {'name': 'Q', 'start': 1878495, 'end': 1879631, 'direction': 'reverse'},
    {'name': 'W', 'start': 1877286, 'end': 1878350, 'direction': 'reverse'},
    {'name': 'U', 'start': 1876923, 'end': 1877267, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(1876923, 1893777)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain SD-LRE2-IT chromosome, complete genome Sequence ID: CP080622.1', fontsize=18, loc='left', fontstyle='italic')
plt.savefig('x Limosilactobacillus reuteri strain SD-LRE2-IT Sequence ID CP080622.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 757476, 'end': 757580, 'direction': 'reverse'},
    {'name': 'EutJ', 'start': 756885, 'end': 757388, 'direction': 'reverse'},
    {'name': '?', 'start': 756524, 'end': 756700, 'direction': 'reverse'},
    {'name': '?', 'start': 756260, 'end': 756490, 'direction': 'reverse'},
    {'name': 'pocR ', 'start': 755094, 'end': 756170, 'direction': 'forward'},
    {'name': 'A', 'start': 754561, 'end': 754839, 'direction': 'reverse'},
    {'name': 'B', 'start': 753855, 'end': 754460, 'direction': 'reverse'},
    {'name': 'C', 'start': 752095, 'end': 753768, 'direction': 'reverse'},
    {'name': 'D', 'start': 751367, 'end': 752074, 'direction': 'reverse'},
    {'name': 'E', 'start': 750839, 'end': 751351, 'direction': 'reverse'},
    {'name': '?', 'start': 750398, 'end': 750805, 'direction': 'reverse'},
    {'name': '?', 'start': 749934, 'end': 750206, 'direction': 'reverse'},
    {'name': 'G', 'start': 749062, 'end': 749973, 'direction': 'reverse'},
    {'name': 'H', 'start': 748716, 'end': 749072, 'direction': 'reverse'},
    {'name': 'K', 'start': 748139, 'end': 748705, 'direction': 'reverse'},
    {'name': 'J', 'start': 747836, 'end': 748123, 'direction': 'reverse'},
    {'name': 'L', 'start': 747163, 'end': 747804, 'direction': 'reverse'},
    {'name': 'M', 'start': 746627, 'end': 747127, 'direction': 'reverse'},
    {'name': 'N', 'start': 746367, 'end': 746636, 'direction': 'reverse'},
    {'name': 'O', 'start': 745899, 'end': 746153, 'direction': 'reverse'},
    {'name': 'Obis', 'start': 745423, 'end': 745893, 'direction': 'reverse'},
    {'name': 'P', 'start': 743987, 'end': 745417, 'direction': 'reverse'},
    {'name': 'Q', 'start': 743436, 'end': 743984, 'direction': 'reverse'},
    {'name': 'U', 'start': 743114, 'end': 743332, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold' 
    elif gene['name'].strip() == '?': 
        facecolor = 'white' 
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(743114, 757580)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain L11 chromosome Sequence ID: CP049758.1', fontsize=18, loc='left', fontstyle='italic')
plt.savefig('x Limosilactobacillus reuteri strain L11 Sequence ID CP049758.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 1451608, 'end': 1452312, 'direction': 'reverse'},
    {'name': 'EutJ', 'start': 1450690, 'end': 1451520, 'direction': 'reverse'},
    {'name': 'pocR ', 'start': 1449565, 'end': 1450641, 'direction': 'forward'},
    {'name': 'A', 'start': 1449032, 'end': 1449310, 'direction': 'reverse'},
    {'name': 'B', 'start': 1448218, 'end': 1448931, 'direction': 'reverse'},
    {'name': 'C', 'start': 1446508, 'end': 1448190, 'direction': 'reverse'},
    {'name': 'D', 'start': 1445780, 'end': 1446487, 'direction': 'reverse'},
    {'name': 'E', 'start': 1445252, 'end': 1445764, 'direction': 'reverse'},
    {'name': 'G', 'start': 1443371, 'end': 1445218, 'direction': 'reverse'},
    {'name': 'H', 'start': 1443025, 'end': 1443381, 'direction': 'reverse'},
    {'name': 'K', 'start': 1442448, 'end': 1443014, 'direction': 'reverse'},
    {'name': 'J', 'start': 1442145, 'end': 1442432, 'direction': 'reverse'},
    {'name': 'L', 'start': 1441472, 'end': 1442113, 'direction': 'reverse'},
    {'name': 'M', 'start': 1440937, 'end': 1441437, 'direction': 'reverse'},
    {'name': 'N', 'start': 1440677, 'end': 1440946, 'direction': 'reverse'},
    {'name': 'O', 'start': 1440069, 'end': 1440653, 'direction': 'reverse'},
    {'name': 'Obis', 'start': 1439593, 'end': 1440063, 'direction': 'reverse'},
    {'name': 'P', 'start': 1438157, 'end': 1439587, 'direction': 'reverse'},
    {'name': 'Q', 'start': 1437003, 'end': 1438139, 'direction': 'reverse'},
    {'name': 'W', 'start': 1435796, 'end': 1436971, 'direction': 'reverse'},
    {'name': 'U', 'start': 1435433, 'end': 1435777, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(1435433, 1452312)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain I49 chromosome, complete genome Sequence ID: CP015408.2', fontsize=18, loc='left', fontstyle='italic')
plt.savefig('x Limosilactobacillus reuteri strain I49 Sequence ID CP015408-2.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 1378406, 'end': 1379110, 'direction': 'forward'},
    {'name': 'EutJ', 'start': 1379198, 'end': 1380028, 'direction': 'forward'},
    {'name': 'pocR ', 'start': 1380336, 'end': 1381310, 'direction': 'reverse'},
    {'name': 'A', 'start': 1381565, 'end': 1381843, 'direction': 'forward'},
    {'name': 'B', 'start': 1381944, 'end': 1382657, 'direction': 'forward'},
    {'name': 'C', 'start': 1382685, 'end': 1384358, 'direction': 'forward'},
    {'name': 'D', 'start': 1384379, 'end': 1385086, 'direction': 'forward'},
    {'name': 'E', 'start': 1385102, 'end': 1385614, 'direction': 'forward'},
    {'name': 'G', 'start': 1385648, 'end': 1387495, 'direction': 'forward'},
    {'name': 'H', 'start': 1387485, 'end': 1387841, 'direction': 'forward'},
    {'name': 'K', 'start': 1387852, 'end': 1388418, 'direction': 'forward'},
    {'name': 'J', 'start': 1388434, 'end': 1388721, 'direction': 'forward'},
    {'name': 'L', 'start': 1388753, 'end': 1389394, 'direction': 'forward'},
    {'name': 'M', 'start': 1389430, 'end': 1389930, 'direction': 'forward'},
    {'name': 'N', 'start': 1389921, 'end': 1390190, 'direction': 'forward'},
    {'name': 'O', 'start': 1390214, 'end': 1390798, 'direction': 'forward'},
    {'name': 'Obis', 'start': 1390804, 'end': 1391274, 'direction': 'forward'},
    {'name': 'P', 'start': 1391280, 'end': 1392710, 'direction': 'forward'},
    {'name': 'Q', 'start': 1392713, 'end': 1393849, 'direction': 'forward'},
    {'name': 'W', 'start': 1393876, 'end': 1395057, 'direction': 'forward'},
    {'name': 'U', 'start': 1395076, 'end': 1395420, 'direction': 'forward'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(1378406, 1395420)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain L8 chromosome Sequence ID: CP049760.1', fontsize=18, loc='left', fontstyle='italic')
plt.savefig('x Limosilactobacillus reuteri strain L8 Sequence ID CP049760.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 1248888, 'end': 1249592, 'direction': 'forward'},
    {'name': 'EutJ ', 'start': 1249680, 'end': 1250510, 'direction': 'forward'},
    {'name': 'pocR ', 'start': 1250661, 'end': 1251635, 'direction': 'reverse'},
    {'name': 'A', 'start': 1251890, 'end': 1252168, 'direction': 'forward'},
    {'name': 'B', 'start': 1252269, 'end': 1252982, 'direction': 'forward'},
    {'name': 'C', 'start': 1253010, 'end': 1254692, 'direction': 'forward'},
    {'name': 'D', 'start': 1254713, 'end': 1255420, 'direction': 'forward'},
    {'name': 'E', 'start': 1255436, 'end': 1255948, 'direction': 'forward'},
    {'name': 'G', 'start': 1255982, 'end': 1257829, 'direction': 'forward'},
    {'name': 'H', 'start': 1257819, 'end': 1258175, 'direction': 'forward'},
    {'name': 'K', 'start': 1258186, 'end': 1258752, 'direction': 'forward'},
    {'name': 'J', 'start': 1258768, 'end': 1259055, 'direction': 'forward'},
    {'name': 'L', 'start': 1259087, 'end': 1259728, 'direction': 'forward'},
    {'name': 'M', 'start': 1259763, 'end': 1260263, 'direction': 'forward'},
    {'name': 'N', 'start': 1260254, 'end': 1260523, 'direction': 'forward'},
    {'name': 'O', 'start': 1260547, 'end': 1261131, 'direction': 'forward'},
    {'name': 'Obis', 'start': 1261137, 'end': 1261607, 'direction': 'forward'},
    {'name': 'P', 'start': 1261613, 'end': 1263043, 'direction': 'forward'},
    {'name': 'Q', 'start': 1263061, 'end': 1264197, 'direction': 'forward'},
    {'name': 'W', 'start': 1264229, 'end': 1265404, 'direction': 'forward'},
    {'name': 'U', 'start': 1265423, 'end': 1265767, 'direction': 'forward'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(1248888, 1265767)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain I49 chromosome Sequence ID: CP065318.1', fontsize=18, loc='left', fontstyle='italic')
plt.savefig('x Limosilactobacillus reuteri strain I49 Sequence ID CP065318.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 2035696, 'end': 2036400, 'direction': 'reverse'},
    {'name': 'EutJ', 'start': 2034778, 'end': 2035608, 'direction': 'reverse'},
    {'name': 'pocR', 'start': 2031979, 'end': 2033055, 'direction': 'forward'},
    {'name': 'A', 'start': 2031446, 'end': 2031724, 'direction': 'reverse'},
    {'name': 'B', 'start': 2030632, 'end': 2031345, 'direction': 'reverse'},
    {'name': 'C', 'start': 2028931, 'end': 2030604, 'direction': 'reverse'},
    {'name': 'D', 'start': 2028203, 'end': 2028910, 'direction': 'reverse'},
    {'name': 'E', 'start': 2027675, 'end': 2028187, 'direction': 'reverse'},
    {'name': 'G', 'start': 2025794, 'end': 2027641, 'direction': 'reverse'},
    {'name': 'H', 'start': 2025448, 'end': 2025804, 'direction': 'reverse'},
    {'name': 'K', 'start': 2024871, 'end': 2025437, 'direction': 'reverse'},
    {'name': 'J', 'start': 2024568, 'end': 2024855, 'direction': 'reverse'},
    {'name': 'L', 'start': 2023895, 'end': 2024536, 'direction': 'reverse'},
    {'name': 'M', 'start': 2023359, 'end': 2023859, 'direction': 'reverse'},
    {'name': 'N', 'start': 2023099, 'end': 2023368, 'direction': 'reverse'},
    {'name': 'O', 'start': 2022491, 'end': 2023075, 'direction': 'reverse'},
    {'name': 'Obis', 'start': 2022015, 'end': 2022485, 'direction': 'reverse'},
    {'name': 'P', 'start': 2020579, 'end': 2022009, 'direction': 'reverse'},
    {'name': 'Q', 'start': 2019440, 'end': 2020576, 'direction': 'reverse'},
    {'name': 'W', 'start': 2018232, 'end': 2019413, 'direction': 'reverse'},
    {'name': 'U', 'start': 2017869, 'end': 2018213, 'direction': 'reverse'},
    {'name': '?', 'start': 2033974, 'end': 2034744, 'direction': 'reverse'},
    {'name': '?', 'start': 2033126, 'end': 2033794, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold' 
    elif gene['name'].strip() == '?': 
        facecolor = 'white' 
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(2017869, 2036400)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain YLR001 chromosome, complete genome Sequence ID: CP065540.1', fontsize=18, loc='left', fontstyle='italic')
plt.savefig('x Limosilactobacillus reuteri strain YLR001 Sequence ID CP065540.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 2101268, 'end': 2101972, 'direction': 'reverse'},
    {'name': 'EutJ ', 'start': 2100350, 'end': 2101180, 'direction': 'reverse'},
    {'name': '?', 'start': 2099546, 'end': 2100316, 'direction': 'reverse'},
    {'name': '?', 'start': 2099046, 'end': 2099366, 'direction': 'reverse'},
    {'name': 'pocR ', 'start': 2097867, 'end': 2098943, 'direction': 'forward'},
    {'name': 'A', 'start': 2097334, 'end': 2097612, 'direction': 'reverse'},
    {'name': 'B', 'start': 2096520, 'end': 2097233, 'direction': 'reverse'},
    {'name': 'C', 'start': 2094819, 'end': 2096492, 'direction': 'reverse'},
    {'name': 'D', 'start': 2094091, 'end': 2094798, 'direction': 'reverse'},
    {'name': 'E', 'start': 2093563, 'end': 2094075, 'direction': 'reverse'},
    {'name': 'G', 'start': 2091682, 'end': 2093529, 'direction': 'reverse'},
    {'name': 'H', 'start': 2091336, 'end': 2091692, 'direction': 'reverse'},
    {'name': 'K', 'start': 2090759, 'end': 2091325, 'direction': 'reverse'},
    {'name': 'J', 'start': 2090456, 'end': 2090743, 'direction': 'reverse'},
    {'name': 'L', 'start': 2089783, 'end': 2090424, 'direction': 'reverse'},
    {'name': 'M', 'start': 2089247, 'end': 2089747, 'direction': 'reverse'},
    {'name': 'N', 'start': 2088987, 'end': 2089256, 'direction': 'reverse'},
    {'name': 'O', 'start': 2088379, 'end': 2088963, 'direction': 'reverse'},
    {'name': 'Obis', 'start': 2087903, 'end': 2088373, 'direction': 'reverse'},
    {'name': 'P', 'start': 2086467, 'end': 2087897, 'direction': 'reverse'},
    {'name': 'Q', 'start': 2085328, 'end': 2086464, 'direction': 'reverse'},
    {'name': 'W', 'start': 2084120, 'end': 2085301, 'direction': 'reverse'},
    {'name': 'U', 'start': 2083757, 'end': 2084101, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold' 
    elif gene['name'].strip() == '?': 
        facecolor = 'white' 
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(2083757, 2101972)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain AM_LB1 chromosome, complete genome Sequence ID: CP104438.1', fontsize=18, loc='left', fontstyle='italic')
plt.savefig('x Limosilactobacillus reuteri strain AM_LB1 Sequence ID CP104438.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 290846, 'end': 291550, 'direction': 'forward'},
    {'name': 'EutJ', 'start': 291626, 'end': 292456, 'direction': 'forward'},
    {'name': 'pocR', 'start': 292645, 'end': 293634, 'direction': 'reverse'},
    {'name': 'A', 'start': 293889, 'end': 294161, 'direction': 'forward'},
    {'name': 'B', 'start': 294265, 'end': 294978, 'direction': 'forward'},
    {'name': 'C', 'start': 295006, 'end': 296679, 'direction': 'forward'},
    {'name': 'D', 'start': 296700, 'end': 297407, 'direction': 'forward'},
    {'name': 'E', 'start': 297424, 'end': 297936, 'direction': 'forward'},
    {'name': 'G', 'start': 297967, 'end': 299811, 'direction': 'forward'},
    {'name': 'H', 'start': 299807, 'end': 300157, 'direction': 'forward'},
    {'name': 'K', 'start': 300168, 'end': 300734, 'direction': 'forward'},
    {'name': 'J', 'start': 300750, 'end': 301034, 'direction': 'forward'},
    {'name': 'L', 'start': 301060, 'end': 301701, 'direction': 'forward'},
    {'name': 'M', 'start': 301735, 'end': 302235, 'direction': 'forward'},
    {'name': 'N', 'start': 302226, 'end': 302495, 'direction': 'forward'},
    {'name': 'O', 'start': 302519, 'end': 303103, 'direction': 'forward'},
    {'name': 'Obis', 'start': 303109, 'end': 303579, 'direction': 'forward'},
    {'name': 'P', 'start': 303585, 'end': 305009, 'direction': 'forward'},
    {'name': 'Q', 'start': 305012, 'end': 306148, 'direction': 'forward'},
    {'name': 'W', 'start': 306175, 'end': 307356, 'direction': 'forward'},
    {'name': 'U', 'start': 307378, 'end': 307722, 'direction': 'forward'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(290846, 307722)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Lactobacillus reuteri, complete genome, strain ATCC 53608 Sequence ID: LN906634.1', fontsize=18, loc='left', fontstyle='italic')
plt.savefig('x Lactobacillus reuteri complete genome strain ATCC 53608 Sequence ID LN906634.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 780623, 'end': 781327, 'direction': 'reverse'},
    {'name': 'EutJ ', 'start': 779789, 'end': 780619, 'direction': 'reverse'},
    {'name': 'pocR ', 'start': 778694, 'end': 779785, 'direction': 'forward'},
    {'name': 'A', 'start': 778415, 'end': 778687, 'direction': 'reverse'},
    {'name': 'B', 'start': 777698, 'end': 778411, 'direction': 'reverse'},
    {'name': 'C', 'start': 776021, 'end': 777694, 'direction': 'reverse'},
    {'name': 'D', 'start': 775310, 'end': 776017, 'direction': 'reverse'},
    {'name': 'E', 'start': 774794, 'end': 775306, 'direction': 'reverse'},
    {'name': 'G', 'start': 772946, 'end': 774790, 'direction': 'reverse'},
    {'name': 'H', 'start': 772592, 'end': 772942, 'direction': 'reverse'},
    {'name': 'K', 'start': 772019, 'end': 772585, 'direction': 'reverse'},
    {'name': 'J', 'start': 771731, 'end': 772015, 'direction': 'reverse'},
    {'name': 'L', 'start': 771086, 'end': 771727, 'direction': 'reverse'},
    {'name': 'M', 'start': 770582, 'end': 771082, 'direction': 'reverse'},
    {'name': 'N', 'start': 770309, 'end': 770578, 'direction': 'reverse'},
    {'name': 'O', 'start': 769715, 'end': 770299, 'direction': 'reverse'},
    {'name': 'Obis', 'start': 769241, 'end': 769711, 'direction': 'reverse'},
    {'name': 'P', 'start': 767813, 'end': 769237, 'direction': 'reverse'},
    {'name': 'Q', 'start': 766691, 'end': 767809, 'direction': 'reverse'},
    {'name': 'W', 'start': 765503, 'end': 766684, 'direction': 'reverse'},
    {'name': 'U', 'start': 765155, 'end': 765499, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(765155, 781327)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain CNEI-KCA3 chromosome, complete genome Sequence ID: CP059275.1', fontsize=18, loc='left', fontstyle='italic')
plt.savefig('x Limosilactobacillus reuteri strain CNEI-KCA3 Sequence ID CP059275.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 142342, 'end': 143046, 'direction': 'reverse'},
    {'name': 'EutJ', 'start': 141436, 'end': 142266, 'direction': 'reverse'},
    {'name': 'pocR', 'start': 140258, 'end': 141349, 'direction': 'forward'},
    {'name': 'A', 'start': 139730, 'end': 140002, 'direction': 'reverse'},
    {'name': 'B', 'start': 138913, 'end': 139626, 'direction': 'reverse'},
    {'name': 'C', 'start': 137212, 'end': 138885, 'direction': 'reverse'},
    {'name': 'D', 'start': 136484, 'end': 137191, 'direction': 'reverse'},
    {'name': 'E', 'start': 135955, 'end': 136467, 'direction': 'reverse'},
    {'name': 'G', 'start': 134863, 'end': 135924, 'direction': 'reverse'},
    {'name': '?', 'start': 134081, 'end': 134833, 'direction': 'reverse'},
    {'name': 'H', 'start': 133735, 'end': 134085, 'direction': 'reverse'},
    {'name': 'K', 'start': 133158, 'end': 133724, 'direction': 'reverse'},
    {'name': 'J', 'start': 132858, 'end': 133142, 'direction': 'reverse'},
    {'name': 'L', 'start': 132191, 'end': 132832, 'direction': 'reverse'},
    {'name': 'M', 'start': 131657, 'end': 132157, 'direction': 'reverse'},
    {'name': 'N', 'start': 131397, 'end': 131666, 'direction': 'reverse'},
    {'name': 'O', 'start': 130789, 'end': 131373, 'direction': 'reverse'},
    {'name': 'Obis', 'start': 130313, 'end': 130783, 'direction': 'reverse'},
    {'name': 'P', 'start': 128883, 'end': 130307, 'direction': 'reverse'},
    {'name': 'Q', 'start': 127744, 'end': 128880, 'direction': 'reverse'},
    {'name': 'W', 'start': 126536, 'end': 127717, 'direction': 'reverse'},
    {'name': 'U', 'start': 126170, 'end': 126514, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    elif gene['name'].strip() == '?': 
        facecolor = 'white'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(126170, 143046)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri subsp. reuteri strain DS0354 chromosome, complete genome Sequence ID: CP146876.1', fontsize=18, loc='left', fontstyle='italic')
plt.savefig('x Limosilactobacillus reuteri subsp. reuteri strain DS0354 Sequence ID CP146876.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 1871690, 'end': 1872394, 'direction': 'forward'},
    {'name': 'EutJ ', 'start': 1872470, 'end': 1873300, 'direction': 'forward'},
    {'name': 'pocR ', 'start': 1873489, 'end': 1874478, 'direction': 'reverse'},
    {'name': 'A', 'start': 1874734, 'end': 1875006, 'direction': 'forward'},
    {'name': 'B', 'start': 1875110, 'end': 1875823, 'direction': 'forward'},
    {'name': 'C', 'start': 1875851, 'end': 1877524, 'direction': 'forward'},
    {'name': 'D', 'start': 1877545, 'end': 1878252, 'direction': 'forward'},
    {'name': 'E', 'start': 1878269, 'end': 1878781, 'direction': 'forward'},
    {'name': 'G', 'start': 1878812, 'end': 1880656, 'direction': 'forward'},
    {'name': 'H', 'start': 1880652, 'end': 1881002, 'direction': 'forward'},
    {'name': 'K', 'start': 1881013, 'end': 1881579, 'direction': 'forward'},
    {'name': 'J', 'start': 1881595, 'end': 1881879, 'direction': 'forward'},
    {'name': 'L', 'start': 1881905, 'end': 1882546, 'direction': 'forward'},
    {'name': 'M', 'start': 1882580, 'end': 1883080, 'direction': 'forward'},
    {'name': 'N', 'start': 1883071, 'end': 1883340, 'direction': 'forward'},
    {'name': 'O', 'start': 1883364, 'end': 1883948, 'direction': 'forward'},
    {'name': 'Obis', 'start': 1883954, 'end': 1884424, 'direction': 'forward'},
    {'name': 'P', 'start': 1884430, 'end': 1885854, 'direction': 'forward'},
    {'name': 'Q', 'start': 1885857, 'end': 1886993, 'direction': 'forward'},
    {'name': 'W', 'start': 1887020, 'end': 1888201, 'direction': 'forward'},
    {'name': 'U', 'start': 1888223, 'end': 1888567, 'direction': 'forward'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    elif gene['name'].strip() == '?': 
        facecolor = 'white'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(1871690, 1888567)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain DS0384 chromosome, complete genome Sequence ID: CP090313.1', fontsize=18, loc='left', fontstyle='italic')
plt.savefig('x Limosilactobacillus reuteri strain DS0384 Sequence ID CP090313.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 1871723, 'end': 1872427, 'direction': 'forward'},
    {'name': 'EutJ', 'start': 1872503, 'end': 1873333, 'direction': 'forward'},
    {'name': 'pocR', 'start': 1873522, 'end': 1874511, 'direction': 'reverse'},
    {'name': 'A', 'start': 1874767, 'end': 1875039, 'direction': 'forward'},
    {'name': 'B', 'start': 1875143, 'end': 1875856, 'direction': 'forward'},
    {'name': 'C', 'start': 1875884, 'end': 1877557, 'direction': 'forward'},
    {'name': 'D', 'start': 1877578, 'end': 1878285, 'direction': 'forward'},
    {'name': 'E', 'start': 1878302, 'end': 1878814, 'direction': 'forward'},
    {'name': 'G', 'start': 1878845, 'end': 1880689, 'direction': 'forward'},
    {'name': 'H', 'start': 1880685, 'end': 1881035, 'direction': 'forward'},
    {'name': 'K', 'start': 1881046, 'end': 1881612, 'direction': 'forward'},
    {'name': 'J', 'start': 1881628, 'end': 1881912, 'direction': 'forward'},
    {'name': 'L', 'start': 1881938, 'end': 1882579, 'direction': 'forward'},
    {'name': 'M', 'start': 1882613, 'end': 1883113, 'direction': 'forward'},
    {'name': 'N', 'start': 1883104, 'end': 1883373, 'direction': 'forward'},
    {'name': 'O', 'start': 1883397, 'end': 1883981, 'direction': 'forward'},
    {'name': 'Obis', 'start': 1883987, 'end': 1884457, 'direction': 'forward'},
    {'name': 'P', 'start': 1884463, 'end': 1885887, 'direction': 'forward'},
    {'name': 'Q', 'start': 1885890, 'end': 1887026, 'direction': 'forward'},
    {'name': 'W', 'start': 1887053, 'end': 1888234, 'direction': 'forward'},
    {'name': 'U', 'start': 1888256, 'end': 1888600, 'direction': 'forward'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    elif gene['name'].strip() == '?': 
        facecolor = 'white'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(1871723, 1888600)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain CUDS0384 chromosome, complete genome Sequence ID: CP147889.1', fontsize=18, loc='left', fontstyle='italic')
plt.savefig('x Limosilactobacillus reuteri strain CUDS0384 Sequence ID CP147889.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 1395857, 'end': 1396561, 'direction': 'reverse'},
    {'name': 'EutJ', 'start': 1394951, 'end': 1395781, 'direction': 'reverse'},
    {'name': 'pocR', 'start': 1393773, 'end': 1394864, 'direction': 'forward'},
    {'name': 'A', 'start': 1393245, 'end': 1393517, 'direction': 'reverse'},
    {'name': 'B', 'start': 1392428, 'end': 1393141, 'direction': 'reverse'},
    {'name': 'C', 'start': 1390727, 'end': 1392400, 'direction': 'reverse'},
    {'name': 'D', 'start': 1389999, 'end': 1390706, 'direction': 'reverse'},
    {'name': 'E', 'start': 1389470, 'end': 1389982, 'direction': 'reverse'},
    {'name': 'G', 'start': 1387595, 'end': 1389439, 'direction': 'reverse'},
    {'name': 'H', 'start': 1387249, 'end': 1387599, 'direction': 'reverse'},
    {'name': 'K', 'start': 1386672, 'end': 1387238, 'direction': 'reverse'},
    {'name': 'J', 'start': 1386372, 'end': 1386656, 'direction': 'reverse'},
    {'name': 'L', 'start': 1385705, 'end': 1386346, 'direction': 'reverse'},
    {'name': 'M', 'start': 1385171, 'end': 1385671, 'direction': 'reverse'},
    {'name': 'N', 'start': 1384911, 'end': 1385180, 'direction': 'reverse'},
    {'name': 'O', 'start': 1384303, 'end': 1384887, 'direction': 'reverse'},
    {'name': 'Obis', 'start': 1383827, 'end': 1384297, 'direction': 'reverse'},
    {'name': 'P', 'start': 1382397, 'end': 1383821, 'direction': 'reverse'},
    {'name': 'Q', 'start': 1381258, 'end': 1382394, 'direction': 'reverse'},
    {'name': 'W', 'start': 1380050, 'end': 1381231, 'direction': 'reverse'},
    {'name': 'U', 'start': 1379684, 'end': 1380028, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    elif gene['name'].strip() == '?': 
        facecolor = 'white'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(1379684, 1396561)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain M2021619 chromosome, complete genome Sequence ID: CP090476.1', fontsize=18, loc='left', fontstyle='italic')
plt.savefig('x Limosilactobacillus reuteri strain M2021619 Sequence ID CP090476.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 1474184, 'end': 1474888, 'direction': 'forward'},
    {'name': 'EutJ', 'start': 1474964, 'end': 1475794, 'direction': 'forward'},
    {'name': 'pocR', 'start': 1475983, 'end': 1476972, 'direction': 'reverse'},
    {'name': 'A', 'start': 1477227, 'end': 1477499, 'direction': 'forward'},
    {'name': 'B', 'start': 1477603, 'end': 1478316, 'direction': 'forward'},
    {'name': 'C', 'start': 1478344, 'end': 1480017, 'direction': 'forward'},
    {'name': 'D', 'start': 1480038, 'end': 1480745, 'direction': 'forward'},
    {'name': 'E', 'start': 1480762, 'end': 1481274, 'direction': 'forward'},
    {'name': 'G', 'start': 1481305, 'end': 1483149, 'direction': 'forward'},
    {'name': 'H', 'start': 1483145, 'end': 1483495, 'direction': 'forward'},
    {'name': 'K', 'start': 1483506, 'end': 1484072, 'direction': 'forward'},
    {'name': 'J', 'start': 1484088, 'end': 1484372, 'direction': 'forward'},
    {'name': 'L', 'start': 1484398, 'end': 1485039, 'direction': 'forward'},
    {'name': 'M', 'start': 1485073, 'end': 1485573, 'direction': 'forward'},
    {'name': 'N', 'start': 1485564, 'end': 1485833, 'direction': 'forward'},
    {'name': 'O', 'start': 1485857, 'end': 1486441, 'direction': 'forward'},
    {'name': 'Obis', 'start': 1486447, 'end': 1486917, 'direction': 'forward'},
    {'name': 'P', 'start': 1486923, 'end': 1488347, 'direction': 'forward'},
    {'name': 'Q', 'start': 1488350, 'end': 1489486, 'direction': 'forward'},
    {'name': 'W', 'start': 1489513, 'end': 1490694, 'direction': 'forward'},
    {'name': 'U', 'start': 1490716, 'end': 1491060, 'direction': 'forward'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    elif gene['name'].strip() == '?': 
        facecolor = 'white'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(1474184, 1491060)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain ZLR003 chromosome, complete genome Sequence ID: CP014786.1', fontsize=18, loc='left', fontstyle='italic')
plt.savefig('x Limosilactobacillus reuteri strain ZLR003 Sequence ID CP014786.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 2027364, 'end': 2028068, 'direction': 'reverse'},
    {'name': 'EutJ', 'start': 2026458, 'end': 2027288, 'direction': 'reverse'},
    {'name': 'pocR', 'start': 2025280, 'end': 2026371, 'direction': 'forward'},
    {'name': 'A', 'start': 2024752, 'end': 2025024, 'direction': 'reverse'},
    {'name': 'B', 'start': 2023935, 'end': 2024648, 'direction': 'reverse'},
    {'name': 'C', 'start': 2022234, 'end': 2023907, 'direction': 'reverse'},
    {'name': 'D', 'start': 2021506, 'end': 2022213, 'direction': 'reverse'},
    {'name': 'E', 'start': 2020977, 'end': 2021489, 'direction': 'reverse'},
    {'name': 'G', 'start': 2019102, 'end': 2020946, 'direction': 'reverse'},
    {'name': 'H', 'start': 2018756, 'end': 2019106, 'direction': 'reverse'},
    {'name': 'K', 'start': 2018179, 'end': 2018745, 'direction': 'reverse'},
    {'name': 'J', 'start': 2017879, 'end': 2018163, 'direction': 'reverse'},
    {'name': 'L', 'start': 2017212, 'end': 2017853, 'direction': 'reverse'},
    {'name': 'M', 'start': 2016678, 'end': 2017178, 'direction': 'reverse'},
    {'name': 'N', 'start': 2016418, 'end': 2016687, 'direction': 'reverse'},
    {'name': 'O', 'start': 2015810, 'end': 2016394, 'direction': 'reverse'},
    {'name': 'Obis', 'start': 2015334, 'end': 2015804, 'direction': 'reverse'},
    {'name': 'P', 'start': 2013904, 'end': 2015328, 'direction': 'reverse'},
    {'name': 'Q', 'start': 2012765, 'end': 2013901, 'direction': 'reverse'},
    {'name': 'W', 'start': 2011557, 'end': 2012738, 'direction': 'reverse'},
    {'name': 'U', 'start': 2011191, 'end': 2011535, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    elif gene['name'].strip() == '?': 
        facecolor = 'white'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(2011191, 2028068)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Limosilactobacillus reuteri strain 1B chromosome, complete genome Sequence ID: CP047416.1', fontsize=18, loc='left', fontstyle='italic')
plt.savefig('x Limosilactobacillus reuteri strain 1B Sequence ID CP047416.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

operon = [
    {'name': 'F', 'start': 919830, 'end': 920534, 'direction': 'reverse'},
    {'name': 'EutJ', 'start': 918924, 'end': 919754, 'direction': 'reverse'},
    {'name': 'pocR', 'start': 917746, 'end': 918837, 'direction': 'forward'},
    {'name': 'A', 'start': 917218, 'end': 917490, 'direction': 'reverse'},
    {'name': 'B', 'start': 916401, 'end': 917114, 'direction': 'reverse'},
    {'name': 'C', 'start': 914700, 'end': 916373, 'direction': 'reverse'},
    {'name': 'D', 'start': 913972, 'end': 914679, 'direction': 'reverse'},
    {'name': 'E', 'start': 913443, 'end': 913955, 'direction': 'reverse'},
    {'name': 'G', 'start': 911568, 'end': 913412, 'direction': 'reverse'},
    {'name': 'H', 'start': 911222, 'end': 911572, 'direction': 'reverse'},
    {'name': 'K', 'start': 910645, 'end': 911211, 'direction': 'reverse'},
    {'name': 'J', 'start': 910345, 'end': 910629, 'direction': 'reverse'},
    {'name': 'L', 'start': 909678, 'end': 910319, 'direction': 'reverse'},
    {'name': 'M', 'start': 909144, 'end': 909644, 'direction': 'reverse'},
    {'name': 'N', 'start': 908884, 'end': 909153, 'direction': 'reverse'},
    {'name': 'O', 'start': 908276, 'end': 908860, 'direction': 'reverse'},
    {'name': 'Obis', 'start': 907800, 'end': 908270, 'direction': 'reverse'},
    {'name': 'P', 'start': 906370, 'end': 907794, 'direction': 'reverse'},
    {'name': 'Q', 'start': 905231, 'end': 906367, 'direction': 'reverse'},
    {'name': 'W', 'start': 904023, 'end': 905204, 'direction': 'reverse'},
    {'name': 'U', 'start': 903657, 'end': 904001, 'direction': 'reverse'},
]

fig, ax = plt.subplots(figsize=(28, 2))
ax.axhline(y=0.3, color='black', linewidth=2, zorder=1)

for gene in operon:
    if gene['name'].strip() == 'pocR': 
        facecolor = 'gold'  
    elif gene['name'].strip() == '?': 
        facecolor = 'white'  
    else:
        facecolor = 'skyblue' if gene['direction'] == 'forward' else 'lightcoral'

    gene_length = gene['end'] - gene['start']
    head_length = gene_length * 0.1  
    
    if gene['direction'] == 'forward':
        arrow = patches.FancyArrow(gene['start'], 0.3, gene_length - head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    else:
        arrow = patches.FancyArrow(gene['end'], 0.3, -gene_length + head_length, 0,
                                   width=0.1, head_width=0.3, head_length=head_length,
                                   facecolor=facecolor, edgecolor='black', linewidth=1)
    
    ax.add_patch(arrow)
    
    ax.text((gene['start'] + gene['end']) / 2, 0.5, gene['name'].strip(), ha='center', va='center', fontsize=16)

ax.set_xlim(903657, 920534)
ax.set_ylim(0, 0.75)
ax.set_yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.set_title('Lactobacillus reuteri SD2112, complete genome Sequence ID: CP002844.1', fontsize=18, loc='left', fontstyle='italic')
plt.savefig('x Lactobacillus reuteri SD2112 Sequence ID CP002844.png', dpi=300, bbox_inches='tight')
plt.show()
